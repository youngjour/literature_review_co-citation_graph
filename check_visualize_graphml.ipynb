# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
G = nx.read_graphml("data/graphml/urban_computing/urban_computing_network.graphml")

# %%
print("Number of nodes:", G.number_of_nodes(), "Number of edges:", G.number_of_edges())
# Out:
# Number of nodes: 35 Number of edges: 595

# %%
for n, data in G.nodes(data=True):
    print(n, data)  # Shows node id and all attributes
# Out:
# ABEL K, 2020, SUSTAIN CITIES SOC {'freq': 2}
# BITLER M, 2011, J POLICY ANAL MANAG {'freq': 2}
# ALKON A, 2013, GEOFORUM {'freq': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE {'freq': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR {'freq': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP {'freq': 2}
# AKIMOTO H, 2003, SCIENCE {'freq': 2}
# ALGERT S, 2006, AM J PREV MED {'freq': 2}
# ADAMS E, 2003, J NUTR {'freq': 2}
# AHVENNIEMI H, 2017, CITIES {'freq': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'freq': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC {'freq': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'freq': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY {'freq': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'freq': 2}
# ALWITT L, 1997, J CONSUM AFF {'freq': 2}
# AJI A, 2013, PROC VLDB ENDOW {'freq': 2}
# AHAS R, 2005, FUTURES {'freq': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH {'freq': 2}
# AN R, 2012, AM J PREV MED {'freq': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'freq': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN {'freq': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'freq': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR {'freq': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC {'freq': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'freq': 2}
# AL M, 2011, J PUBLIC TRANSPORT {'freq': 2}
# AHERN M, 2011, J RURAL HEALTH {'freq': 2}
# AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'freq': 2}
# ABUL O, 2008, PROC INT CONF DATA {'freq': 2}
# ANKERST M, 1999, SIGMOD RECORD {'freq': 2}
# ALKON A, 2012, BLACK {'freq': 2}
# ALLCOTT H, 2019, Q J ECON {'freq': 2}
# ATASH F, 1994, J URBAN PLAN D-ASCE {'freq': 2}
# AGGARWAL A, 2014, AM J PUBLIC HEALTH {'freq': 2}

# %%
G.edges
# Out:
# EdgeView([('ABEL K, 2020, SUSTAIN CITIES SOC', 'AAZAM M, 2018, FUTURE GENER COMP SY'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ABADI A, 2015, IEEE T INTELL TRANSP'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ABEYKOON A, 2017, PUBLIC HEALTH NUTR'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ABUL O, 2008, PROC INT CONF DATA'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ABUSABHA R, 2011, J AM DIET ASSOC'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ADAMS E, 2003, J NUTR'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018)'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AGGARWAL A, 2014, AM J PUBLIC HEALTH'), ('ABEL K, 2020, SUSTAIN CITIES SOC', "AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS"), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AHAS R, 2005, FUTURES'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AHERN M, 2011, J RURAL HEALTH'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AHVENNIEMI H, 2017, CITIES'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AIJAZ A, 2013, IEEE WIREL COMMUN'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AIRHIHENBUWA C, 1996, ETHN HEALTH'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AJI A, 2013, PROC VLDB ENDOW'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AJZEN I, 1991, ORGAN BEHAV HUM DEC'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AKIMOTO H, 2003, SCIENCE'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AL M, 2011, J PUBLIC TRANSPORT'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ALGERT S, 2006, AM J PREV MED'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ALKON A, 2012, BLACK'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ALKON A, 2013, GEOFORUM'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ALLCOTT H, 2019, Q J ECON'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ALWITT L, 1997, J CONSUM AFF'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'AN R, 2012, AM J PREV MED'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ANDREYEVA T, 2008, HEALTH AFFAIR'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ANKERST M, 1999, SIGMOD RECORD'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'APPARICIO P, 2007, INT J HEALTH GEOGR'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'APPLEBY G, 2020, AAAI CONF ARTIF INTE'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'ATASH F, 1994, J URBAN PLAN D-ASCE'), ('ABEL K, 2020, SUSTAIN CITIES SOC', 'BITLER M, 2011, J POLICY ANAL MANAG'), ('ABEL K, 2020, SUSTAIN CITIES SOC', '[ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS]'), ('ABEL K, 2020, SUSTAIN CITIES SOC', '[ANONYMOUS], 2013, P 8 INT C BOD AR NET'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'AAZAM M, 2018, FUTURE GENER COMP SY'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'ABADI A, 2015, IEEE T INTELL TRANSP'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'ABEYKOON A, 2017, PUBLIC HEALTH NUTR'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'ABUL O, 2008, PROC INT CONF DATA'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'ABUSABHA R, 2011, J AM DIET ASSOC'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'ADAMS E, 2003, J NUTR'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018)'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'AGGARWAL A, 2014, AM J PUBLIC HEALTH'), ('BITLER M, 2011, J POLICY ANAL MANAG', "AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS"), ('BITLER M, 2011, J POLICY ANAL MANAG', 'AHAS R, 2005, FUTURES'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'AHERN M, 2011, J RURAL HEALTH'), ('BITLER M, 2011, J POLICY ANAL MANAG', 'AHVENNIEMI H, 2017, CITIES'), ('BITLER M, 2011, J POLICY ANAL MANAG',  ...

# %%
for u, v, edata in G.edges(data=True):
    print(u, v, edata)  # Shows the edge and attributes
# Out:
# ABEL K, 2020, SUSTAIN CITIES SOC AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ABADI A, 2015, IEEE T INTELL TRANSP {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ADAMS E, 2003, J NUTR {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AHAS R, 2005, FUTURES {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AHVENNIEMI H, 2017, CITIES {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AKIMOTO H, 2003, SCIENCE {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ALGERT S, 2006, AM J PREV MED {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ALKON A, 2012, BLACK {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ALKON A, 2013, GEOFORUM {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC AN R, 2012, AM J PREV MED {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ANDREYEVA T, 2008, HEALTH AFFAIR {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC APPLEBY G, 2020, AAAI CONF ARTIF INTE {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC BITLER M, 2011, J POLICY ANAL MANAG {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ABEL K, 2020, SUSTAIN CITIES SOC [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ABADI A, 2015, IEEE T INTELL TRANSP {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ADAMS E, 2003, J NUTR {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AHAS R, 2005, FUTURES {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AHVENNIEMI H, 2017, CITIES {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AKIMOTO H, 2003, SCIENCE {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ALGERT S, 2006, AM J PREV MED {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ALKON A, 2012, BLACK {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ALKON A, 2013, GEOFORUM {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ALLCOTT H, 2019, Q J ECON {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG AN R, 2012, AM J PREV MED {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ANDREYEVA T, 2008, HEALTH AFFAIR {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG APPLEBY G, 2020, AAAI CONF ARTIF INTE {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# BITLER M, 2011, J POLICY ANAL MANAG [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ALKON A, 2013, GEOFORUM AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ALKON A, 2013, GEOFORUM ABADI A, 2015, IEEE T INTELL TRANSP {'weight': 2}
# ALKON A, 2013, GEOFORUM ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# ALKON A, 2013, GEOFORUM ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ALKON A, 2013, GEOFORUM ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ALKON A, 2013, GEOFORUM ADAMS E, 2003, J NUTR {'weight': 2}
# ALKON A, 2013, GEOFORUM ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# ALKON A, 2013, GEOFORUM AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ALKON A, 2013, GEOFORUM AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ALKON A, 2013, GEOFORUM AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ALKON A, 2013, GEOFORUM AHAS R, 2005, FUTURES {'weight': 2}
# ALKON A, 2013, GEOFORUM AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ALKON A, 2013, GEOFORUM AHVENNIEMI H, 2017, CITIES {'weight': 2}
# ALKON A, 2013, GEOFORUM AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ALKON A, 2013, GEOFORUM AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ALKON A, 2013, GEOFORUM AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ALKON A, 2013, GEOFORUM AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# ALKON A, 2013, GEOFORUM AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ALKON A, 2013, GEOFORUM AKIMOTO H, 2003, SCIENCE {'weight': 2}
# ALKON A, 2013, GEOFORUM AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ALKON A, 2013, GEOFORUM ALGERT S, 2006, AM J PREV MED {'weight': 2}
# ALKON A, 2013, GEOFORUM ALKON A, 2012, BLACK {'weight': 2}
# ALKON A, 2013, GEOFORUM ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ALKON A, 2013, GEOFORUM ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ALKON A, 2013, GEOFORUM AN R, 2012, AM J PREV MED {'weight': 2}
# ALKON A, 2013, GEOFORUM ANDREYEVA T, 2008, HEALTH AFFAIR {'weight': 2}
# ALKON A, 2013, GEOFORUM ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ALKON A, 2013, GEOFORUM APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ALKON A, 2013, GEOFORUM APPLEBY G, 2020, AAAI CONF ARTIF INTE {'weight': 2}
# ALKON A, 2013, GEOFORUM ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ALKON A, 2013, GEOFORUM [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ALKON A, 2013, GEOFORUM [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ABADI A, 2015, IEEE T INTELL TRANSP {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ADAMS E, 2003, J NUTR {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AHAS R, 2005, FUTURES {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AHVENNIEMI H, 2017, CITIES {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AKIMOTO H, 2003, SCIENCE {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ALGERT S, 2006, AM J PREV MED {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ALKON A, 2012, BLACK {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ALLCOTT H, 2019, Q J ECON {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE AN R, 2012, AM J PREV MED {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ANDREYEVA T, 2008, HEALTH AFFAIR {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# APPLEBY G, 2020, AAAI CONF ARTIF INTE [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ABADI A, 2015, IEEE T INTELL TRANSP {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ADAMS E, 2003, J NUTR {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AHAS R, 2005, FUTURES {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AHVENNIEMI H, 2017, CITIES {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AKIMOTO H, 2003, SCIENCE {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ALGERT S, 2006, AM J PREV MED {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ALKON A, 2012, BLACK {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR AN R, 2012, AM J PREV MED {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ANDREYEVA T, 2008, HEALTH AFFAIR [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ADAMS E, 2003, J NUTR {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AHAS R, 2005, FUTURES {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AHVENNIEMI H, 2017, CITIES {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AKIMOTO H, 2003, SCIENCE {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ALGERT S, 2006, AM J PREV MED {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ALKON A, 2012, BLACK {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP AN R, 2012, AM J PREV MED {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ABADI A, 2015, IEEE T INTELL TRANSP [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ADAMS E, 2003, J NUTR {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AHAS R, 2005, FUTURES {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AHVENNIEMI H, 2017, CITIES {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ALGERT S, 2006, AM J PREV MED {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ALKON A, 2012, BLACK {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# AKIMOTO H, 2003, SCIENCE AN R, 2012, AM J PREV MED {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AKIMOTO H, 2003, SCIENCE APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AKIMOTO H, 2003, SCIENCE ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AKIMOTO H, 2003, SCIENCE [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AKIMOTO H, 2003, SCIENCE [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ADAMS E, 2003, J NUTR {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AHAS R, 2005, FUTURES {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AHVENNIEMI H, 2017, CITIES {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ALKON A, 2012, BLACK {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ALGERT S, 2006, AM J PREV MED AN R, 2012, AM J PREV MED {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ALGERT S, 2006, AM J PREV MED APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ALGERT S, 2006, AM J PREV MED ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ALGERT S, 2006, AM J PREV MED [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ALGERT S, 2006, AM J PREV MED [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ADAMS E, 2003, J NUTR AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ADAMS E, 2003, J NUTR ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# ADAMS E, 2003, J NUTR ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ADAMS E, 2003, J NUTR ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ADAMS E, 2003, J NUTR ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# ADAMS E, 2003, J NUTR AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ADAMS E, 2003, J NUTR AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ADAMS E, 2003, J NUTR AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ADAMS E, 2003, J NUTR AHAS R, 2005, FUTURES {'weight': 2}
# ADAMS E, 2003, J NUTR AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ADAMS E, 2003, J NUTR AHVENNIEMI H, 2017, CITIES {'weight': 2}
# ADAMS E, 2003, J NUTR AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ADAMS E, 2003, J NUTR AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ADAMS E, 2003, J NUTR AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ADAMS E, 2003, J NUTR AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# ADAMS E, 2003, J NUTR AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ADAMS E, 2003, J NUTR AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ADAMS E, 2003, J NUTR ALKON A, 2012, BLACK {'weight': 2}
# ADAMS E, 2003, J NUTR ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ADAMS E, 2003, J NUTR ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ADAMS E, 2003, J NUTR AN R, 2012, AM J PREV MED {'weight': 2}
# ADAMS E, 2003, J NUTR ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ADAMS E, 2003, J NUTR APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ADAMS E, 2003, J NUTR ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ADAMS E, 2003, J NUTR [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ADAMS E, 2003, J NUTR [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AHAS R, 2005, FUTURES {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ALKON A, 2012, BLACK {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# AHVENNIEMI H, 2017, CITIES AN R, 2012, AM J PREV MED {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AHVENNIEMI H, 2017, CITIES APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AHVENNIEMI H, 2017, CITIES ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AHVENNIEMI H, 2017, CITIES [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AHVENNIEMI H, 2017, CITIES [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AHAS R, 2005, FUTURES {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AJZEN I, 1991, ORGAN BEHAV HUM DEC {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ALKON A, 2012, BLACK {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN AN R, 2012, AM J PREV MED {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ADOMAVICIUS G, 2005, IEEE T KNOWL DATA EN [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ABEYKOON A, 2017, PUBLIC HEALTH NUTR {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AHAS R, 2005, FUTURES {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ALKON A, 2012, BLACK {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC AN R, 2012, AM J PREV MED {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AJZEN I, 1991, ORGAN BEHAV HUM DEC [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AAZAM M, 2018, FUTURE GENER COMP SY {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AHAS R, 2005, FUTURES {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR ALKON A, 2012, BLACK {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR AN R, 2012, AM J PREV MED {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ABEYKOON A, 2017, PUBLIC HEALTH NUTR [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AHAS R, 2005, FUTURES {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY ALKON A, 2012, BLACK {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY AN R, 2012, AM J PREV MED {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AAZAM M, 2018, FUTURE GENER COMP SY [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AHAS R, 2005, FUTURES {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE ALKON A, 2012, BLACK {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE ALWITT L, 1997, J CONSUM AFF {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE AN R, 2012, AM J PREV MED {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AKAGI Y, 2018, PROCEEDINGS OF THE TWENTY-SEVENTH INTERNATIONAL JOINT CONFERENCE ON ARTIFICIAL INTELLIGENCE [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AHAS R, 2005, FUTURES {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AJI A, 2013, PROC VLDB ENDOW {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF ALKON A, 2012, BLACK {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF AN R, 2012, AM J PREV MED {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# ALWITT L, 1997, J CONSUM AFF [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AHAS R, 2005, FUTURES {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW ALKON A, 2012, BLACK {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW AN R, 2012, AM J PREV MED {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AJI A, 2013, PROC VLDB ENDOW [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AHAS R, 2005, FUTURES ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AHAS R, 2005, FUTURES ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AHAS R, 2005, FUTURES AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AHAS R, 2005, FUTURES AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AHAS R, 2005, FUTURES AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AHAS R, 2005, FUTURES AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AHAS R, 2005, FUTURES AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AHAS R, 2005, FUTURES AIRHIHENBUWA C, 1996, ETHN HEALTH {'weight': 2}
# AHAS R, 2005, FUTURES AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AHAS R, 2005, FUTURES ALKON A, 2012, BLACK {'weight': 2}
# AHAS R, 2005, FUTURES ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AHAS R, 2005, FUTURES AN R, 2012, AM J PREV MED {'weight': 2}
# AHAS R, 2005, FUTURES ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AHAS R, 2005, FUTURES APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AHAS R, 2005, FUTURES ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AHAS R, 2005, FUTURES [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AHAS R, 2005, FUTURES [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH ALKON A, 2012, BLACK {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH AN R, 2012, AM J PREV MED {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AIRHIHENBUWA C, 1996, ETHN HEALTH [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AN R, 2012, AM J PREV MED ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AN R, 2012, AM J PREV MED ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AN R, 2012, AM J PREV MED AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AN R, 2012, AM J PREV MED AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AN R, 2012, AM J PREV MED AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS {'weight': 2}
# AN R, 2012, AM J PREV MED AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AN R, 2012, AM J PREV MED AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AN R, 2012, AM J PREV MED AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AN R, 2012, AM J PREV MED ALKON A, 2012, BLACK {'weight': 2}
# AN R, 2012, AM J PREV MED ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AN R, 2012, AM J PREV MED ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AN R, 2012, AM J PREV MED APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AN R, 2012, AM J PREV MED ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AN R, 2012, AM J PREV MED [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AN R, 2012, AM J PREV MED [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS AIJAZ A, 2013, IEEE WIREL COMMUN {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS ALKON A, 2012, BLACK {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AGRAWAL R, 1993, FOUNDATIONS OF DATA ORGANIZATION AND ALGORITHMS 4TH INTERNATIONAL CONFERENCE FODO '93 PROCEEDINGS [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN ALKON A, 2012, BLACK {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] {'weight': 2}
# AIJAZ A, 2013, IEEE WIREL COMMUN [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] ALKON A, 2012, BLACK {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] ALLCOTT H, 2019, Q J ECON {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] APPARICIO P, 2007, INT J HEALTH GEOGR {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# [ANONYMOUS], 2012, CENSUS TRACT LEVEL STATE MAPS OF THE MODIFIED RETAIL FOOD ENVIRONMENT INDEX (MRFEI) [ANONYMOUS] [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR ABUSABHA R, 2011, J AM DIET ASSOC {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR ALKON A, 2012, BLACK {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR ALLCOTT H, 2019, Q J ECON {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# APPARICIO P, 2007, INT J HEALTH GEOGR [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC ALKON A, 2012, BLACK {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ABUSABHA R, 2011, J AM DIET ASSOC [ANONYMOUS], 2013, P 8 INT C BOD AR NET {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET AL M, 2011, J PUBLIC TRANSPORT {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET ALKON A, 2012, BLACK {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET ALLCOTT H, 2019, Q J ECON {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# [ANONYMOUS], 2013, P 8 INT C BOD AR NET ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT AHERN M, 2011, J RURAL HEALTH {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT ALKON A, 2012, BLACK {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AL M, 2011, J PUBLIC TRANSPORT ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AHERN M, 2011, J RURAL HEALTH ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AHERN M, 2011, J RURAL HEALTH AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) {'weight': 2}
# AHERN M, 2011, J RURAL HEALTH AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AHERN M, 2011, J RURAL HEALTH ALKON A, 2012, BLACK {'weight': 2}
# AHERN M, 2011, J RURAL HEALTH ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AHERN M, 2011, J RURAL HEALTH ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AHERN M, 2011, J RURAL HEALTH ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) ABUL O, 2008, PROC INT CONF DATA {'weight': 2}
# AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) ALKON A, 2012, BLACK {'weight': 2}
# AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) ALLCOTT H, 2019, Q J ECON {'weight': 2}
# AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# AGARAP A, 2018, PROCEEDINGS OF 2018 10TH INTERNATIONAL CONFERENCE ON MACHINE LEARNING AND COMPUTING (ICMLC 2018) ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ABUL O, 2008, PROC INT CONF DATA AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ABUL O, 2008, PROC INT CONF DATA ALKON A, 2012, BLACK {'weight': 2}
# ABUL O, 2008, PROC INT CONF DATA ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ABUL O, 2008, PROC INT CONF DATA ANKERST M, 1999, SIGMOD RECORD {'weight': 2}
# ABUL O, 2008, PROC INT CONF DATA ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ANKERST M, 1999, SIGMOD RECORD AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ANKERST M, 1999, SIGMOD RECORD ALKON A, 2012, BLACK {'weight': 2}
# ANKERST M, 1999, SIGMOD RECORD ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ANKERST M, 1999, SIGMOD RECORD ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ALKON A, 2012, BLACK AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ALKON A, 2012, BLACK ALLCOTT H, 2019, Q J ECON {'weight': 2}
# ALKON A, 2012, BLACK ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ALLCOTT H, 2019, Q J ECON AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}
# ALLCOTT H, 2019, Q J ECON ATASH F, 1994, J URBAN PLAN D-ASCE {'weight': 2}
# ATASH F, 1994, J URBAN PLAN D-ASCE AGGARWAL A, 2014, AM J PUBLIC HEALTH {'weight': 2}

# %%
plt.figure(figsize=(8, 6))  # You can adjust the figure size

# A layout for the graph (spring layout is common, but there are others)
pos = nx.spring_layout(G)  

# Draw nodes, edges, and labels
nx.draw_networkx_nodes(G, pos)
nx.draw_networkx_edges(G, pos)
nx.draw_networkx_labels(G, pos)

plt.title("GraphML Visualization")
plt.axis("off")  # Hide the axes for clarity
plt.show()

# %%
pos = {}
for node, data in G.nodes(data=True):
    try:
        # Convert the 'year' attribute to int
        x_coord = int(data["year"])
    except (ValueError, TypeError):
        x_coord = 0  # fallback if missing or invalid
    
    # Use a small random or jitter for the y-axis, so nodes do not all stack
    y_coord = random.uniform(-0.5, 0.5)  
    pos[node] = (x_coord, y_coord)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 5
#       2 for node, data in G.nodes(data=True):
#       3     try:
#       4         # Convert the 'year' attribute to int
# ----> 5         x_coord = int(data["year"])
#       6     except (ValueError, TypeError):
#       7         x_coord = 0  # fallback if missing or invalid
#
# KeyError: 'year'

# %%
plt.figure(figsize=(10, 6))

# Draw edges with thickness proportional to 'weight'
# (If many edges, might be slow. For clarity, we can scale or set alpha.)
edge_widths = []
for u, v, edata in G.edges(data=True):
    # Example: scale the line width a bit
    w = edata.get("weight", 1.0)
    edge_widths.append(0.5 + w * 0.5)  # or any scaling you prefer

nx.draw_networkx_edges(G, pos=pos, width=edge_widths, alpha=0.5)

# Draw nodes
nx.draw_networkx_nodes(G, pos=pos, node_size=50)

plt.title("Co-Citation Network Positioned by Publication Year")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 11
#       8     w = edata.get("weight", 1.0)
#       9     edge_widths.append(0.5 + w * 0.5)  # or any scaling you prefer
# ---> 11 nx.draw_networkx_edges(G, pos=pos, width=edge_widths, alpha=0.5)
#      13 # Draw nodes
#      14 nx.draw_networkx_nodes(G, pos=pos, node_size=50)
#
# File c:\Users\STIL\anaconda3\envs\yj_env\Lib\site-packages\networkx\drawing\nx_pylab.py:977, in draw_networkx_edges(G, pos, edgelist, width, edge_color, style, alpha, arrowstyle, arrowsize, edge_cmap, edge_vmin, edge_vmax, ax, arrows, label, node_size, nodelist, node_shape, connectionstyle, min_source_margin, min_target_margin, hide_ticks)
#     974     edge_color = "k"
#     976 # set edge positions
# --> 977 edge_pos = np.asarray([(pos[e[0]], pos[e[1]]) for e in edgelist])
#     979 # Check if edge_color is an array of floats and map to edge_cmap.
#     980 # This is the only case handled differently from matplotlib
#     981 if (
#     982     np.iterable(edge_color)
#     983     and (len(edge_color) == len(edge_pos))
#     984     and np.all([isinstance(c, Number) for c in edge_color])
#     985 ):
#
# KeyError: 'ABEL K, 2020, SUSTAIN CITIES SOC'

# %%
from networkx.algorithms import community

communities = community.greedy_modularity_communities(G)
# communities is a list of sets of node IDs

# Create a dict mapping node -> community_index
node_community_map = {}
for i, cset in enumerate(communities):
    for node in cset:
        node_community_map[node] = i

# %%
all_communities = community.greedy_modularity_communities(G)
print(f"Total communities found: {len(all_communities)}")

# Sort communities by size descending
sorted_communities = sorted(all_communities, key=lambda c: len(c), reverse=True)

# Decide how many communities you want to keep:
#   Option A: Keep the top K biggest communities
K = 10
big_communities = sorted_communities[:K]
# Out:
# Total communities found: 127

# %%
node_community_map = {}
for i, cset in enumerate(big_communities):
    for node in cset:
        node_community_map[node] = i

num_communities = len(big_communities)

# %%
big_nodes = set().union(*big_communities)

G_big = G.subgraph(big_nodes).copy()

betw = nx.betweenness_centrality(G_big)  # returns dict: node -> centrality

# %%
pos2 = {}
for node, data in G_big.nodes(data=True):
    # Convert node's 'year' to int if possible
    try:
        year_val = int(data.get("year", 0))
    except ValueError:
        year_val = 0
    
    # Find the node's community index; default -1 if not found
    comm_idx = node_community_map.get(node, -1)
    
    # Add a small random offset so nodes don’t overlap exactly
    offset = random.uniform(-0.3, 0.3)
    pos2[node] = (year_val, comm_idx + offset)

# %%
nodelist = list(G_big.nodes())

community_colors = []
node_sizes = []

for n in nodelist:
    # figure out the community index for node n
    c_idx = node_community_map[n]
    community_colors.append(c_idx)

    # compute betweenness-based size
    # (betw might have been computed on G_big or original G, just be consistent)
    score = betw[n]
    node_sizes.append(50 + 900 * score)

# %%
max_betw = max(betw.values()) if betw else 1.0  # avoid zero division if empty

# %%
for n in G_big.nodes():
    c_index = node_community_map.get(n, -1)
    community_colors.append(c_index)
    
    # Scale betweenness into, say, [100, 1000] for node size
    node_sizes.append(100 + 900 * (betw[n] / max_betw))

# %%
node_sizes = []
for n in nodelist:
    # Get freq value from node attributes; default to 1 if missing
    freq_val = G_big.nodes[n].get("freq", 1)
    # Scale freq to get a visible size, e.g. freq * 50
    node_sizes.append(freq_val * 50)

# %%
labels_for_nodes = {}
for n in nodelist:
    freq_val = G_big.nodes[n].get("freq", 1)
    if freq_val >= 10:
        # Label this node with its NodeID
        labels_for_nodes[n] = str(n)

# %%
all_years = []
for n, data in G_big.nodes(data=True):
    try:
        yr = int(data.get("year", 0))
        all_years.append(yr)
    except ValueError:
        # Some nodes may have invalid year string
        all_years.append(0)

if not all_years:
    # fallback if no years found
    all_years = [0, 1]

min_year = min(all_years)
max_year = max(all_years)

# %%
plt.figure(figsize=(30, 15))

nx.draw_networkx_edges(G_big, pos=pos2, alpha=0.3, width=1, connectionstyle='arc3,rad=0.5')

nx.draw_networkx_nodes(
    G_big, pos=pos2,
    nodelist=nodelist,
    node_color=community_colors,
    node_size=node_sizes,
    cmap=plt.cm.tab10
)

nx.draw_networkx_labels(
    G_big,
    pos=pos2,
    labels=labels_for_nodes,
    font_size=8,
    font_color="black"  # or any color you prefer
)

plt.title("Co-Citation Network by Year and Community")
plt.xlabel("Publication Year")
plt.ylabel("Clutering Communities")
plt.xticks(range(min_year, max_year + 1, 2))  
plt.ylim(-1, num_communities + 1)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\jour\AppData\Local\Temp\ipykernel_45500\2001336574.py:3: UserWarning:
#
# The connectionstyle keyword argument is not applicable when drawing edges
# with LineCollection.
#
# To make this warning go away, either specify `arrows=True` to
# force FancyArrowPatches or use the default values.
# Note that using FancyArrowPatches may be slow for large graphs.
#
#   nx.draw_networkx_edges(G_big, pos=pos2, alpha=0.3, width=1, connectionstyle='arc3,rad=0.5')

# %%
# plt.figure(figsize=(12, 6))

# # Draw edges
# #   (Edges may connect nodes in different communities or across years)
# nx.draw_networkx_edges(
#     G_big, pos=pos2,
#     alpha=0.3,
#     width=1
# )

# # Draw nodes with colors = community index, sizes = betweenness
# nx.draw_networkx_nodes(
#     G_big, pos=pos2,
#     node_color=community_colors,
#     node_size=node_sizes,
#     cmap=plt.cm.tab10  # color map for up to 10 communities; adapt as needed
# )

# # Build a dictionary of labels ONLY for top nodes
# top_node_ids = [node_id for node_id, bc in top_nodes]
# labels_for_top_nodes = {n: str(n) for n in top_node_ids}  

# # Label only these nodes (NodeID as text)
# nx.draw_networkx_labels(G, pos=pos2, labels=labels_for_top_nodes, font_size=7)

# plt.title("Co-Citation Network by Year (X) and Community (Y)")
# plt.xlabel("Publication Year")
# plt.ylabel("Community Index")
# plt.ylim(-1, num_communities + 1)  # extra space at top/bottom
# plt.tight_layout()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 12
#       5 nx.draw_networkx_edges(
#       6     G_big, pos=pos2,
#       7     alpha=0.3,
#       8     width=1
#       9 )
#      11 # Draw nodes with colors = community index, sizes = betweenness
# ---> 12 nx.draw_networkx_nodes(
#      13     G_big, pos=pos2,
#      14     node_color=community_colors,
#      15     node_size=node_sizes,
#      16     cmap=plt.cm.tab10  # color map for up to 10 communities; adapt as needed
#      17 )
#      19 # Build a dictionary of labels ONLY for top nodes
#      20 top_node_ids = [node_id for node_id, bc in top_nodes]
#
# File c:\Users\jour\anaconda3\envs\yj_env\Lib\site-packages\networkx\drawing\nx_pylab.py:457, in draw_networkx_nodes(G, pos, nodelist, node_size, node_color, node_shape, alpha, cmap, vmin, vmax, ax, linewidths, edgecolors, label, margins, hide_ticks)
#     454     node_shape = np.array([node_shape for _ in range(len(nodelist))])
#     456 for shape in np.unique(node_shape):
# --> 457     node_collection = ax.scatter(
#     458         xy[node_shape == shape, 0],
#     459         xy[node_shape == shape, 1],
#     460         s=node_size,
#     461         c=node_color,
#     462         marker=shape,
#     463         cmap=cmap,
#     464         vmin=vmin,
#     465         vmax=vmax,
#     466         alpha=alpha,
#     467         linewidths=linewidths,
#     468         edgecolors=edgecolors,
#     469         label=label,
#     470     )
#     471 if hide_ticks:
#     472     ax.tick_params(
#     473         axis="both",
#     474         which="both",
#    (...)
#     478         labelleft=False,
#     479     )
#
# File c:\Users\jour\anaconda3\envs\yj_env\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File c:\Users\jour\anaconda3\envs\yj_env\Lib\site-packages\matplotlib\axes\_axes.py:4796, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4792 s = np.ma.ravel(s)
#    4793 if (len(s) not in (1, x.size) or
#    4794         (not np.issubdtype(s.dtype, np.floating) and
#    4795          not np.issubdtype(s.dtype, np.integer))):
# -> 4796     raise ValueError(
#    4797         "s must be a scalar, "
#    4798         "or float array-like with the same size as x and y")
#    4800 # get the original edgecolor the user passed before we normalize
#    4801 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y

# %%
num_top = 50
sorted_nodes = sorted(betw.items(), key=lambda x: x[1], reverse=True)
top_nodes = sorted_nodes[:num_top]

print(f"Top {num_top} important nodes by Betweenness Centrality:")
for rank, (node_id, bc) in enumerate(top_nodes, start=1):
    label_str = G.nodes[node_id].get("label", "NoLabel")
    print(f"{rank:2d}. NodeID={node_id}, Betw={bc:.4f}, label={label_str}")
# Out:
# Top 50 important nodes by Betweenness Centrality:
#  1. NodeID=915, Betw=0.0987, label=Walker RE, 2010, HEALTH PLACE, V16, P876, DOI 10.1016/j.healthplace.2010.04.013
#  2. NodeID=665, Betw=0.0867, label=Cummins S, 2014, HEALTH AFFAIR, V33, P283, DOI 10.1377/hlthaff.2013.0512
#  3. NodeID=250, Betw=0.0797, label=Shaw HJ, 2006, GEOGR ANN B, V88B, P231, DOI 10.1111/j.0435-3684.2006.00217.x
#  4. NodeID=582, Betw=0.0482, label=Department of Health, 1998, INDEPENDENT INQUIRY, V0, P0
#  5. NodeID=533, Betw=0.0444, label=Clarke G, 2002, URBAN STUD, V39, P2041, DOI 10.1080/0042098022000011353
#  6. NodeID=455, Betw=0.0410, label=MacNell L, 2017, J HUNGER ENVIRON NUT, V12, P375, DOI 10.1080/19320248.2017.1284025
#  7. NodeID=276, Betw=0.0375, label=Wrigley N, 2002, URBAN STUD, V39, P2029, DOI 10.1080/0042098022000011344
#  8. NodeID=233, Betw=0.0364, label=Burgoine T, 2013, INT J BEHAV NUTR PHY, V10, P0, DOI 10.1186/1479-5868-10-85
#  9. NodeID=952, Betw=0.0348, label=Ploeg MV, 2015, APPL ECON PERSPECT P, V37, P205, DOI 10.1093/aepp/ppu035
# 10. NodeID=297, Betw=0.0346, label=Wrigley N, 2002, URBAN STUD, V39, P2061, DOI 10.1080/0042098022000011362
# 11. NodeID=244, Betw=0.0341, label=Zenk SN, 2005, AM J PUBLIC HEALTH, V95, P660, DOI 10.2105/AJPH.2004.042150
# 12. NodeID=112, Betw=0.0311, label=Abeykoon AMH, 2017, PUBLIC HEALTH NUTR, V20, P2236, DOI 10.1017/s1368980017000933, 10.1017/S1368980017000933
# 13. NodeID=20, Betw=0.0294, label=Apparicio P, 2007, INT J HEALTH GEOGR, V6, P0, DOI 10.1186/1476-072X-6-4
# 14. NodeID=328, Betw=0.0270, label=LeDoux TF, 2013, HEALTH PLACE, V19, P1, DOI 10.1016/j.healthplace.2012.09.010
# 15. NodeID=367, Betw=0.0265, label=Chen DH, 2016, AM J PUBLIC HEALTH, V106, P881, DOI 10.2105/AJPH.2016.303048
# 16. NodeID=209, Betw=0.0259, label=Berkowitz SA, 2018, DIABETES CARE, V41, P1188, DOI 10.2337/dc17-1981
# 17. NodeID=828, Betw=0.0247, label=Hager ER, 2017, PUBLIC HEALTH NUTR, V20, P2598, DOI 10.1017/S1368980016002123
# 18. NodeID=560, Betw=0.0232, label=De Master KT, 2019, AGR HUM VALUES, V36, P241, DOI 10.1007/s10460-019-09914-5
# 19. NodeID=981, Betw=0.0225, label=Anderson AS, 2007, PUBLIC HEALTH NUTR, V10, P1440, DOI 10.1017/S1368980007000092
# 20. NodeID=137, Betw=0.0217, label=Chen X, 2013, APPL GEOGR, V43, P81, DOI 10.1016/j.apgeog.2013.05.012
# 21. NodeID=207, Betw=0.0207, label=Dubowitz T, 2015, HEALTH AFFAIR, V34, P1858, DOI 10.1377/hlthaff.2015.0667
# 22. NodeID=486, Betw=0.0199, label=Helbich M, 2017, APPL GEOGR, V83, P1, DOI 10.1016/j.apgeog.2017.02.015
# 23. NodeID=126, Betw=0.0186, label=Chrisinger B, 2016, J URBAN HEALTH, V93, P425, DOI 10.1007/s11524-016-0055-8
# 24. NodeID=47, Betw=0.0181, label=Dubowitz T, 2015, PUBLIC HEALTH NUTR, V18, P2220, DOI 10.1017/S1368980014002742
# 25. NodeID=752, Betw=0.0179, label=Franco M, 2008, AM J PREV MED, V35, P561, DOI 10.1016/j.amepre.2008.07.003
# 26. NodeID=185, Betw=0.0173, label=*ELCHA, 1999, FOOD ACC E LOND E LO, V0, P0
# 27. NodeID=799, Betw=0.0172, label=Raja S, 2008, J PLAN EDUC RES, V27, P469, DOI 10.1177/0739456X08317461
# 28. NodeID=627, Betw=0.0172, label=Widener MJ, 2011, AM J PREV MED, V41, P439, DOI 10.1016/j.amepre.2011.06.034
# 29. NodeID=89, Betw=0.0165, label=Cannuscio CC, 2014, SOC SCI MED, V122, P13, DOI 10.1016/j.socscimed.2014.10.005
# 30. NodeID=116, Betw=0.0164, label=Hillier A, 2011, URBAN GEOGR, V32, P712, DOI 10.2747/0272-3638.32.5.712
# 31. NodeID=783, Betw=0.0160, label=Allcott H, 2019, Q J ECON, V134, P1793, DOI 10.1093/qje/qjz015
# 32. NodeID=766, Betw=0.0159, label=An RP, 2012, AM J PREV MED, V42, P129, DOI 10.1016/j.amepre.2011.10.012
# 33. NodeID=30, Betw=0.0159, label=Andreyeva T, 2008, HEALTH AFFAIR, V27, P1381, DOI 10.1377/hlthaff.27.5.1381
# 34. NodeID=593, Betw=0.0158, label=Chen X, 2016, PROF GEOGR, V68, P175, DOI 10.1080/00330124.2015.1032876
# 35. NodeID=280, Betw=0.0157, label=Hendrickson D, 2006, AGR HUM VALUES, V23, P371, DOI 10.1007/s10460-006-9002-8
# 36. NodeID=256, Betw=0.0149, label=Hubley TA, 2011, APPL GEOGR, V31, P1224, DOI 10.1016/j.apgeog.2010.09.004
# 37. NodeID=547, Betw=0.0148, label=Jiao JF, 2012, AM J PUBLIC HEALTH, V102, PE32, DOI 10.2105/AJPH.2012.300675
# 38. NodeID=145, Betw=0.0144, label=Caspi CE, 2016, PUBLIC HEALTH NUTR, V19, P540, DOI 10.1017/S1368980015002724
# 39. NodeID=9, Betw=0.0144, label=Larsen K, 2008, INT J HEALTH GEOGR, V7, P0, DOI 10.1186/1476-072X-7-16
# 40. NodeID=571, Betw=0.0140, label=Cummins S, 2002, BRIT MED J, V325, P436, DOI 10.1136/bmj.325.7361.436
# 41. NodeID=996, Betw=0.0138, label=Bridle-Fitzpatrick S, 2015, SOC SCI MED, V142, P202, DOI 10.1016/j.socscimed.2015.08.010
# 42. NodeID=629, Betw=0.0136, label=Cooksey-Stowers K, 2017, INT J ENV RES PUB HE, V14, P0, DOI 10.3390/ijerph14111366
# 43. NodeID=768, Betw=0.0136, label=Kelli HM, 2019, J AM HEART ASSOC, V8, P0, DOI 10.1161/JAHA.118.010694
# 44. NodeID=961, Betw=0.0130, label=*M GALL RES CONS G, 2006, GOOD FOOD EX IMP FOO, V0, P0
# 45. NodeID=478, Betw=0.0127, label=Widener MJ, 2012, J URBAN HEALTH, V89, P733, DOI 10.1007/s11524-012-9677-7
# 46. NodeID=723, Betw=0.0126, label=Andreyeva T, 2012, J ACAD NUTR DIET, V112, P850, DOI 10.1016/j.jand.2012.02.019
# 47. NodeID=713, Betw=0.0125, label=Wrigley N, 2003, ENVIRON PLANN A, V35, P151, DOI 10.1068/a35150
# 48. NodeID=715, Betw=0.0125, label=Lee H, 2012, SOC SCI MED, V74, P1193, DOI 10.1016/j.socscimed.2011.12.036
# 49. NodeID=794, Betw=0.0122, label=Ghosh-Dastidar M, 2017, HEALTH PLACE, V46, P249, DOI 10.1016/j.healthplace.2017.06.002
# 50. NodeID=897, Betw=0.0122, label=McKinnon RA, 2009, AM J PREV MED, V36, PS124, DOI 10.1016/j.amepre.2009.01.012

# %%
comm_dataframes = {}

for i, cset in enumerate(communities):
    rows = []
    for node_id in cset:
        # Retrieve node attributes
        node_data = G.nodes[node_id]
        
        # For example, you might want columns like:
        # NodeID, name, label, year, freq, etc.
        rows.append({
            "NodeID": node_id,
            "name": node_data.get("name", ""),
            "label": node_data.get("label", ""),
            "year": node_data.get("year", ""),
            "freq": node_data.get("freq", None)
        })
    
    # Convert to a DataFrame
    df = pd.DataFrame(rows)
    
    # Store in dictionary
    comm_dataframes[i] = df

# %%
comm_dataframes[0].sort_values('freq', ascending = False).head(15)
# Out:
#     NodeID              name  \
# 182    915         Walker RE
# 51       9          Larsen K
# 25     766             An RP
# 195    715             Lee H
# 170     20       Apparicio P
# 145    296         Larson NI
# 143    328         LeDoux TF
# 203    547           Jiao JF
# 237    273          Caspi CE
# 140    389  Boone-Heinonen J
# 74     702         Beaulac J
# 26     799            Raja S
# 29     256         Hubley TA
# 12     469        Widener MJ
# 61     128         McEntee J
#
#                                                  label  year  freq
# 182  Walker RE, 2010, HEALTH PLACE, V16, P876, DOI ...  2010    44
# 51   Larsen K, 2008, INT J HEALTH GEOGR, V7, P0, DO...  2008    32
# 25   An RP, 2012, AM J PREV MED, V42, P129, DOI 10....  2012    32
# 195  Lee H, 2012, SOC SCI MED, V74, P1193, DOI 10.1...  2012    29
# 170  Apparicio P, 2007, INT J HEALTH GEOGR, V6, P0,...  2007    28
# 145  Larson NI, 2009, AM J PREV MED, V36, P74, DOI ...  2009    27
# 143  LeDoux TF, 2013, HEALTH PLACE, V19, P1, DOI 10...  2013    26
# 203  Jiao JF, 2012, AM J PUBLIC HEALTH, V102, PE32,...  2012    25
# 237  Caspi CE, 2012, HEALTH PLACE, V18, P1172, DOI ...  2012    25
# 140  Boone-Heinonen J, 2011, ARCH INTERN MED, V171,...  2011    25
# 74           Beaulac J, 2009, PREV CHRONIC DIS, V6, P0  2009    24
# 26   Raja S, 2008, J PLAN EDUC RES, V27, P469, DOI ...  2008    23
# 29   Hubley TA, 2011, APPL GEOGR, V31, P1224, DOI 1...  2011    18
# 12   Widener MJ, 2013, HEALTH PLACE, V21, P1, DOI 1...  2013    18
# 61   McEntee J, 2010, APPL GEOGR, V30, P165, DOI 10...  2010    17

# %% [markdown]
# ### Time-series Co-citation Network Analysis

# %%
# Collect all years from edges
edge_years = []
for u, v, edata in G.edges(data=True):
    if "year" in edata and edata["year"]:
        edge_years.append(edata["year"])

unique_years = sorted(set(edge_years))

print("All edge years in the graph:", unique_years)
# Out:
# All edge years in the graph: ['1996', '1998', '1999', '2000', '2001', '2002', '2003', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']

# %%
subgraphs_by_year = {}
for y in unique_years:
    edges_this_year = [
        (u, v) for (u, v, edata) in G.edges(data=True)
        if edata.get("year") == y
    ]
    subG = G.edge_subgraph(edges_this_year).copy()
    subgraphs_by_year[y] = subG

# %%
from networkx.algorithms import community

for y in unique_years:
    subG = subgraphs_by_year[y]
    if subG.number_of_nodes() == 0:
        print(f"Year {y}: no edges or nodes.")
        continue
    
    # Find communities using Greedy Modularity
    communities = community.greedy_modularity_communities(subG)
    
    print(f"Year {y} - Number of communities detected: {len(communities)}")
    
    # communities is a list (or list-like) of sets of nodes
    for i, comm in enumerate(communities):
        print(f"  Community {i}: {len(comm)} nodes")
        # If you want, you can list them all:
        # print(comm)
# Out:
# Year 1996 - Number of communities detected: 1
#   Community 0: 6 nodes
# Year 1998 - Number of communities detected: 3
#   Community 0: 15 nodes
#   Community 1: 7 nodes
#   Community 2: 3 nodes
# Year 1999 - Number of communities detected: 2
#   Community 0: 9 nodes
#   Community 1: 5 nodes
# Year 2000 - Number of communities detected: 2
#   Community 0: 23 nodes
#   Community 1: 9 nodes
# Year 2001 - Number of communities detected: 2
#   Community 0: 5 nodes
#   Community 1: 5 nodes
# Year 2002 - Number of communities detected: 7
#   Community 0: 10 nodes
#   Community 1: 7 nodes
#   Community 2: 7 nodes
#   Community 3: 6 nodes
#   Community 4: 3 nodes
#   Community 5: 2 nodes
#   Community 6: 2 nodes
# Year 2003 - Number of communities detected: 4
#   Community 0: 15 nodes
#   Community 1: 6 nodes
#   Community 2: 3 nodes
#   Community 3: 2 nodes
# Year 2005 - Number of communities detected: 3
#   Community 0: 9 nodes
#   Community 1: 9 nodes
#   Community 2: 6 nodes
# Year 2006 - Number of communities detected: 6
#   Community 0: 10 nodes
#   Community 1: 8 nodes
#   Community 2: 5 nodes
#   Community 3: 4 nodes
#   Community 4: 2 nodes
#   Community 5: 2 nodes
# Year 2007 - Number of communities detected: 6
#   Community 0: 9 nodes
#   Community 1: 6 nodes
#   Community 2: 6 nodes
#   Community 3: 5 nodes
#   Community 4: 4 nodes
#   Community 5: 2 nodes
# Year 2008 - Number of communities detected: 4
#   Community 0: 16 nodes
#   Community 1: 3 nodes
#   Community 2: 2 nodes
#   Community 3: 2 nodes
# Year 2009 - Number of communities detected: 5
#   Community 0: 11 nodes
#   Community 1: 10 nodes
#   Community 2: 10 nodes
#   Community 3: 9 nodes
#   Community 4: 2 nodes
# Year 2010 - Number of communities detected: 7
#   Community 0: 17 nodes
#   Community 1: 16 nodes
#   Community 2: 15 nodes
#   Community 3: 9 nodes
#   Community 4: 7 nodes
#   Community 5: 3 nodes
#   Community 6: 2 nodes
# Year 2011 - Number of communities detected: 6
#   Community 0: 18 nodes
#   Community 1: 11 nodes
#   Community 2: 9 nodes
#   Community 3: 7 nodes
#   Community 4: 7 nodes
#   Community 5: 2 nodes
# Year 2012 - Number of communities detected: 7
#   Community 0: 18 nodes
#   Community 1: 12 nodes
#   Community 2: 10 nodes
#   Community 3: 6 nodes
#   Community 4: 5 nodes
#   Community 5: 5 nodes
#   Community 6: 2 nodes
# Year 2013 - Number of communities detected: 5
#   Community 0: 21 nodes
#   Community 1: 15 nodes
#   Community 2: 13 nodes
#   Community 3: 9 nodes
#   Community 4: 5 nodes
# Year 2014 - Number of communities detected: 8
#   Community 0: 29 nodes
#   Community 1: 19 nodes
#   Community 2: 11 nodes
#   Community 3: 7 nodes
#   Community 4: 7 nodes
#   Community 5: 5 nodes
#   Community 6: 2 nodes
#   Community 7: 2 nodes
# Year 2015 - Number of communities detected: 7
#   Community 0: 17 nodes
#   Community 1: 15 nodes
#   Community 2: 15 nodes
#   Community 3: 13 nodes
#   Community 4: 5 nodes
#   Community 5: 4 nodes
#   Community 6: 2 nodes
# Year 2016 - Number of communities detected: 8
#   Community 0: 18 nodes
#   Community 1: 14 nodes
#   Community 2: 9 nodes
#   Community 3: 9 nodes
#   Community 4: 7 nodes
#   Community 5: 5 nodes
#   Community 6: 4 nodes
#   Community 7: 2 nodes
# Year 2017 - Number of communities detected: 7
#   Community 0: 15 nodes
#   Community 1: 15 nodes
#   Community 2: 13 nodes
#   Community 3: 13 nodes
#   Community 4: 11 nodes
#   Community 5: 4 nodes
#   Community 6: 3 nodes
# Year 2018 - Number of communities detected: 6
#   Community 0: 17 nodes
#   Community 1: 14 nodes
#   Community 2: 11 nodes
#   Community 3: 10 nodes
#   Community 4: 3 nodes
#   Community 5: 2 nodes
# Year 2019 - Number of communities detected: 7
#   Community 0: 16 nodes
#   Community 1: 12 nodes
#   Community 2: 12 nodes
#   Community 3: 9 nodes
#   Community 4: 9 nodes
#   Community 5: 3 nodes
#   Community 6: 2 nodes
# Year 2020 - Number of communities detected: 7
#   Community 0: 14 nodes
#   Community 1: 14 nodes
#   Community 2: 12 nodes
#   Community 3: 12 nodes
#   Community 4: 3 nodes
#   Community 5: 2 nodes
#   Community 6: 2 nodes
# Year 2021 - Number of communities detected: 8
#   Community 0: 18 nodes
#   Community 1: 17 nodes
#   Community 2: 11 nodes
#   Community 3: 6 nodes
#   Community 4: 5 nodes
#   Community 5: 5 nodes
#   Community 6: 3 nodes
#   Community 7: 3 nodes
# Year 2022 - Number of communities detected: 7
#   Community 0: 19 nodes
#   Community 1: 17 nodes
#   Community 2: 8 nodes
#   Community 3: 8 nodes
#   Community 4: 7 nodes
#   Community 5: 4 nodes
#   Community 6: 3 nodes
# Year 2023 - Number of communities detected: 7
#   Community 0: 16 nodes
#   Community 1: 8 nodes
#   Community 2: 6 nodes
#   Community 3: 4 nodes
#   Community 4: 3 nodes
#   Community 5: 2 nodes
#   Community 6: 2 nodes
# Year 2024 - Number of communities detected: 11
#   Community 0: 20 nodes
#   Community 1: 12 nodes
#   Community 2: 9 nodes
#   Community 3: 4 nodes
#   Community 4: 4 nodes
#   Community 5: 3 nodes
#   Community 6: 3 nodes
#   Community 7: 3 nodes
#   Community 8: 2 nodes
#   Community 9: 2 nodes
#   Community 10: 2 nodes

# %%
from networkx.algorithms.community.quality import modularity

partition = list(communities)  # a list of sets
mod = modularity(subG, partition)
print(f"Modularity = {mod:.4f}")
# Out:
# Modularity = 0.4652

# %%
# Identifying Important Literature in Each Community
degree_cent = nx.degree_centrality(subG)
betweenness_cent = nx.betweenness_centrality(subG)
pagerank = nx.pagerank(subG)

# Sort nodes by their degree centrality (descending)
sorted_by_degree = sorted(degree_cent.items(), key=lambda x: x[1], reverse=True)
print("Top 5 by degree centrality in subG:")
for node, val in sorted_by_degree[:5]:
    print(f"Node {node} - Degree centrality: {val:.4f}")
# Out:
# Top 5 by degree centrality in subG:
# Node 611 - Degree centrality: 0.2540
# Node 292 - Degree centrality: 0.2381
# Node 453 - Degree centrality: 0.2381
# Node 438 - Degree centrality: 0.2381
# Node 140 - Degree centrality: 0.2381

# %%
for i, comm in enumerate(communities):
    comm_subG = subG.subgraph(comm).copy()
    # Compute page rank inside the community
    pr = nx.pagerank(comm_subG)

    # Sort by pagerank
    top_nodes = sorted(pr.items(), key=lambda x: x[1], reverse=True)[:5]
    print(f"  Top 5 PageRank nodes in Community {i}:")
    for node, score in top_nodes:
        print(f"    {node}: {score:.4f}")
# Out:
#   Top 5 PageRank nodes in Community 0:
#     438: 0.0792
#     140: 0.0743
#     292: 0.0710
#     926: 0.0703
#     560: 0.0688
#   Top 5 PageRank nodes in Community 1:
#     701: 0.1184
#     257: 0.1184
#     548: 0.1184
#     930: 0.1182
#     905: 0.0873
#   Top 5 PageRank nodes in Community 2:
#     473: 0.1882
#     60: 0.1437
#     555: 0.1423
#     895: 0.1312
#     591: 0.1225
#   Top 5 PageRank nodes in Community 3:
#     784: 0.3164
#     919: 0.3049
#     274: 0.1951
#     751: 0.1836
#   Top 5 PageRank nodes in Community 4:
#     31: 0.3047
#     806: 0.2857
#     222: 0.2857
#     835: 0.1238
#   Top 5 PageRank nodes in Community 5:
#     405: 0.4865
#     269: 0.2568
#     76: 0.2568
#   Top 5 PageRank nodes in Community 6:
#     381: 0.3333
#     110: 0.3333
#     41: 0.3333
#   Top 5 PageRank nodes in Community 7:
#     127: 0.4865
#     504: 0.2568
#     18: 0.2568
#   Top 5 PageRank nodes in Community 8:
#     406: 0.5000
#     73: 0.5000
#   Top 5 PageRank nodes in Community 9:
#     412: 0.5000
#     819: 0.5000
#   Top 5 PageRank nodes in Community 10:
#     545: 0.5000
#     275: 0.5000

# %%
for y in unique_years:
    subG = subgraphs_by_year[y]
    if subG.number_of_nodes() == 0:
        continue
    
    communities = community.greedy_modularity_communities(subG)
    # Convert the community sets into a node->community_index mapping
    node_community_map = {}
    for i, c in enumerate(communities):
        for node in c:
            node_community_map[node] = i
    
    # Draw the subgraph
    plt.figure()
    pos = nx.spring_layout(subG, seed=42)
    
    # To color by community, we can make a list of color values for each node
    community_indices = [node_community_map[n] for n in subG.nodes()]
    nx.draw_networkx_nodes(
        subG,
        pos=pos,
        node_size=200,
        node_color=community_indices,  # color nodes by their community index
        cmap=plt.cm.tab10  # or other matplotlib colormap
    )
    nx.draw_networkx_edges(subG, pos=pos, alpha=0.5)
    nx.draw_networkx_labels(subG, pos=pos, font_size=6)

    plt.title(f"Year {y} - Communities")
    plt.axis("off")
    plt.show()

# %%
# Static Detection + Matching by Overlap over Years

# %%
def jaccard_similarity(setA, setB):
    """
    Computes Jaccard similarity: |A ∩ B| / |A ∪ B|.
    Returns 0 if both sets are empty.
    """
    if not setA and not setB:  # both empty
        return 0
    return len(setA & setB) / len(setA | setB)

# %%
comp = community.girvan_newman(subG)

# %%
communities_t = next(comp)

# %%
communities_by_year = {}
for y in unique_years:
    subG = subgraphs_by_year[y]
    if subG.number_of_nodes() == 0:
        communities_by_year[y] = []
    else:
        # This gives you a list (or list-like) of sets of nodes
        communities = community.greedy_modularity_communities(subG)
        communities_by_year[y] = communities

# %%
for i in range(len(unique_years) - 1):
    y1 = unique_years[i]
    y2 = unique_years[i + 1]
    
    communities_t     = communities_by_year[y1]     # communities in year y1
    communities_tplus = communities_by_year[y2]     # communities in year y2
    
    match_results = {}
    for idx, comm_t in enumerate(communities_t):
        best_jaccard = 0
        best_index = None

        for j, comm_tplus_ in enumerate(communities_tplus):
            sim = jaccard_similarity(comm_t, comm_tplus_)
            if sim > best_jaccard:
                best_jaccard = sim
                best_index = j
        
        match_results[idx] = (best_index, best_jaccard)

    print(f"--- Matching Communities from Year {y1} to Year {y2} ---")
    for comm_idx, (matched_comm_idx, score) in match_results.items():
        print(
            f"Community {comm_idx} in {y1} best matches "
            f"Community {matched_comm_idx} in {y2} with Jaccard={score:.3f}"
        )
    print()
# Out:
# --- Matching Communities from Year 1996 to Year 1998 ---
# Community 0 in 1996 best matches Community None in 1998 with Jaccard=0.000
#
# --- Matching Communities from Year 1998 to Year 1999 ---
# Community 0 in 1998 best matches Community None in 1999 with Jaccard=0.000
# Community 1 in 1998 best matches Community None in 1999 with Jaccard=0.000
# Community 2 in 1998 best matches Community None in 1999 with Jaccard=0.000
#
# --- Matching Communities from Year 1999 to Year 2000 ---
# Community 0 in 1999 best matches Community None in 2000 with Jaccard=0.000
# Community 1 in 1999 best matches Community None in 2000 with Jaccard=0.000
#
# --- Matching Communities from Year 2000 to Year 2001 ---
# Community 0 in 2000 best matches Community None in 2001 with Jaccard=0.000
# Community 1 in 2000 best matches Community None in 2001 with Jaccard=0.000
#
# --- Matching Communities from Year 2001 to Year 2002 ---
# Community 0 in 2001 best matches Community None in 2002 with Jaccard=0.000
# Community 1 in 2001 best matches Community None in 2002 with Jaccard=0.000
#
# --- Matching Communities from Year 2002 to Year 2003 ---
# Community 0 in 2002 best matches Community None in 2003 with Jaccard=0.000
# Community 1 in 2002 best matches Community 0 in 2003 with Jaccard=0.048
# Community 2 in 2002 best matches Community 3 in 2003 with Jaccard=0.125
# Community 3 in 2002 best matches Community 1 in 2003 with Jaccard=0.091
# Community 4 in 2002 best matches Community None in 2003 with Jaccard=0.000
# Community 5 in 2002 best matches Community None in 2003 with Jaccard=0.000
# Community 6 in 2002 best matches Community None in 2003 with Jaccard=0.000
#
# --- Matching Communities from Year 2003 to Year 2005 ---
# Community 0 in 2003 best matches Community None in 2005 with Jaccard=0.000
# Community 1 in 2003 best matches Community None in 2005 with Jaccard=0.000
# Community 2 in 2003 best matches Community None in 2005 with Jaccard=0.000
# Community 3 in 2003 best matches Community None in 2005 with Jaccard=0.000
#
# --- Matching Communities from Year 2005 to Year 2006 ---
# Community 0 in 2005 best matches Community None in 2006 with Jaccard=0.000
# Community 1 in 2005 best matches Community None in 2006 with Jaccard=0.000
# Community 2 in 2005 best matches Community None in 2006 with Jaccard=0.000
#
# --- Matching Communities from Year 2006 to Year 2007 ---
# Community 0 in 2006 best matches Community None in 2007 with Jaccard=0.000
# Community 1 in 2006 best matches Community None in 2007 with Jaccard=0.000
# Community 2 in 2006 best matches Community None in 2007 with Jaccard=0.000
# Community 3 in 2006 best matches Community 2 in 2007 with Jaccard=0.111
# Community 4 in 2006 best matches Community 0 in 2007 with Jaccard=0.100
# Community 5 in 2006 best matches Community None in 2007 with Jaccard=0.000
#
# --- Matching Communities from Year 2007 to Year 2008 ---
# Community 0 in 2007 best matches Community None in 2008 with Jaccard=0.000
# Community 1 in 2007 best matches Community None in 2008 with Jaccard=0.000
# Community 2 in 2007 best matches Community None in 2008 with Jaccard=0.000
# Community 3 in 2007 best matches Community None in 2008 with Jaccard=0.000
# Community 4 in 2007 best matches Community None in 2008 with Jaccard=0.000
# Community 5 in 2007 best matches Community None in 2008 with Jaccard=0.000
#
# --- Matching Communities from Year 2008 to Year 2009 ---
# Community 0 in 2008 best matches Community None in 2009 with Jaccard=0.000
# Community 1 in 2008 best matches Community None in 2009 with Jaccard=0.000
# Community 2 in 2008 best matches Community None in 2009 with Jaccard=0.000
# Community 3 in 2008 best matches Community None in 2009 with Jaccard=0.000
#
# --- Matching Communities from Year 2009 to Year 2010 ---
# Community 0 in 2009 best matches Community 1 in 2010 with Jaccard=0.125
# Community 1 in 2009 best matches Community None in 2010 with Jaccard=0.000
# Community 2 in 2009 best matches Community 0 in 2010 with Jaccard=0.174
# Community 3 in 2009 best matches Community 4 in 2010 with Jaccard=0.067
# Community 4 in 2009 best matches Community None in 2010 with Jaccard=0.000
#
# --- Matching Communities from Year 2010 to Year 2011 ---
# Community 0 in 2010 best matches Community 0 in 2011 with Jaccard=0.167
# Community 1 in 2010 best matches Community 0 in 2011 with Jaccard=0.172
# Community 2 in 2010 best matches Community 3 in 2011 with Jaccard=0.048
# Community 3 in 2010 best matches Community 3 in 2011 with Jaccard=0.067
# Community 4 in 2010 best matches Community 3 in 2011 with Jaccard=0.077
# Community 5 in 2010 best matches Community None in 2011 with Jaccard=0.000
# Community 6 in 2010 best matches Community None in 2011 with Jaccard=0.000
#
# --- Matching Communities from Year 2011 to Year 2012 ---
# Community 0 in 2011 best matches Community 0 in 2012 with Jaccard=0.091
# Community 1 in 2011 best matches Community 2 in 2012 with Jaccard=0.105
# Community 2 in 2011 best matches Community 2 in 2012 with Jaccard=0.056
# Community 3 in 2011 best matches Community 4 in 2012 with Jaccard=0.091
# Community 4 in 2011 best matches Community 2 in 2012 with Jaccard=0.062
# Community 5 in 2011 best matches Community None in 2012 with Jaccard=0.000
#
# --- Matching Communities from Year 2012 to Year 2013 ---
# Community 0 in 2012 best matches Community 1 in 2013 with Jaccard=0.100
# Community 1 in 2012 best matches Community None in 2013 with Jaccard=0.000
# Community 2 in 2012 best matches Community 2 in 2013 with Jaccard=0.045
# Community 3 in 2012 best matches Community 2 in 2013 with Jaccard=0.056
# Community 4 in 2012 best matches Community 0 in 2013 with Jaccard=0.040
# Community 5 in 2012 best matches Community 4 in 2013 with Jaccard=0.111
# Community 6 in 2012 best matches Community None in 2013 with Jaccard=0.000
#
# --- Matching Communities from Year 2013 to Year 2014 ---
# Community 0 in 2013 best matches Community 0 in 2014 with Jaccard=0.111
# Community 1 in 2013 best matches Community 0 in 2014 with Jaccard=0.048
# Community 2 in 2013 best matches Community 0 in 2014 with Jaccard=0.050
# Community 3 in 2013 best matches Community 6 in 2014 with Jaccard=0.100
# Community 4 in 2013 best matches Community 3 in 2014 with Jaccard=0.091
#
# --- Matching Communities from Year 2014 to Year 2015 ---
# Community 0 in 2014 best matches Community 1 in 2015 with Jaccard=0.128
# Community 1 in 2014 best matches Community 3 in 2015 with Jaccard=0.067
# Community 2 in 2014 best matches Community 2 in 2015 with Jaccard=0.040
# Community 3 in 2014 best matches Community 6 in 2015 with Jaccard=0.125
# Community 4 in 2014 best matches Community 3 in 2015 with Jaccard=0.053
# Community 5 in 2014 best matches Community None in 2015 with Jaccard=0.000
# Community 6 in 2014 best matches Community None in 2015 with Jaccard=0.000
# Community 7 in 2014 best matches Community 3 in 2015 with Jaccard=0.071
#
# --- Matching Communities from Year 2015 to Year 2016 ---
# Community 0 in 2015 best matches Community 2 in 2016 with Jaccard=0.083
# Community 1 in 2015 best matches Community 2 in 2016 with Jaccard=0.091
# Community 2 in 2015 best matches Community 2 in 2016 with Jaccard=0.043
# Community 3 in 2015 best matches Community 0 in 2016 with Jaccard=0.069
# Community 4 in 2015 best matches Community 1 in 2016 with Jaccard=0.056
# Community 5 in 2015 best matches Community 0 in 2016 with Jaccard=0.048
# Community 6 in 2015 best matches Community None in 2016 with Jaccard=0.000
#
# --- Matching Communities from Year 2016 to Year 2017 ---
# Community 0 in 2016 best matches Community 2 in 2017 with Jaccard=0.192
# Community 1 in 2016 best matches Community 3 in 2017 with Jaccard=0.080
# Community 2 in 2016 best matches Community 3 in 2017 with Jaccard=0.048
# Community 3 in 2016 best matches Community 1 in 2017 with Jaccard=0.091
# Community 4 in 2016 best matches Community 0 in 2017 with Jaccard=0.100
# Community 5 in 2016 best matches Community 5 in 2017 with Jaccard=0.125
# Community 6 in 2016 best matches Community None in 2017 with Jaccard=0.000
# Community 7 in 2016 best matches Community 3 in 2017 with Jaccard=0.071
#
# --- Matching Communities from Year 2017 to Year 2018 ---
# Community 0 in 2017 best matches Community 1 in 2018 with Jaccard=0.074
# Community 1 in 2017 best matches Community 3 in 2018 with Jaccard=0.087
# Community 2 in 2017 best matches Community 1 in 2018 with Jaccard=0.125
# Community 3 in 2017 best matches Community 3 in 2018 with Jaccard=0.045
# Community 4 in 2017 best matches Community 2 in 2018 with Jaccard=0.158
# Community 5 in 2017 best matches Community 2 in 2018 with Jaccard=0.071
# Community 6 in 2017 best matches Community None in 2018 with Jaccard=0.000
#
# --- Matching Communities from Year 2018 to Year 2019 ---
# Community 0 in 2018 best matches Community 4 in 2019 with Jaccard=0.083
# Community 1 in 2018 best matches Community 3 in 2019 with Jaccard=0.045
# Community 2 in 2018 best matches Community 3 in 2019 with Jaccard=0.053
# Community 3 in 2018 best matches Community 3 in 2019 with Jaccard=0.056
# Community 4 in 2018 best matches Community None in 2019 with Jaccard=0.000
# Community 5 in 2018 best matches Community 1 in 2019 with Jaccard=0.077
#
# --- Matching Communities from Year 2019 to Year 2020 ---
# Community 0 in 2019 best matches Community 3 in 2020 with Jaccard=0.037
# Community 1 in 2019 best matches Community None in 2020 with Jaccard=0.000
# Community 2 in 2019 best matches Community 1 in 2020 with Jaccard=0.083
# Community 3 in 2019 best matches Community 2 in 2020 with Jaccard=0.105
# Community 4 in 2019 best matches Community 0 in 2020 with Jaccard=0.095
# Community 5 in 2019 best matches Community None in 2020 with Jaccard=0.000
# Community 6 in 2019 best matches Community None in 2020 with Jaccard=0.000
#
# --- Matching Communities from Year 2020 to Year 2021 ---
# Community 0 in 2020 best matches Community 0 in 2021 with Jaccard=0.143
# Community 1 in 2020 best matches Community 3 in 2021 with Jaccard=0.053
# Community 2 in 2020 best matches Community 1 in 2021 with Jaccard=0.036
# Community 3 in 2020 best matches Community None in 2021 with Jaccard=0.000
# Community 4 in 2020 best matches Community None in 2021 with Jaccard=0.000
# Community 5 in 2020 best matches Community None in 2021 with Jaccard=0.000
# Community 6 in 2020 best matches Community None in 2021 with Jaccard=0.000
#
# --- Matching Communities from Year 2021 to Year 2022 ---
# Community 0 in 2021 best matches Community 0 in 2022 with Jaccard=0.057
# Community 1 in 2021 best matches Community 1 in 2022 with Jaccard=0.030
# Community 2 in 2021 best matches Community 4 in 2022 with Jaccard=0.059
# Community 3 in 2021 best matches Community None in 2022 with Jaccard=0.000
# Community 4 in 2021 best matches Community None in 2022 with Jaccard=0.000
# Community 5 in 2021 best matches Community 1 in 2022 with Jaccard=0.048
# Community 6 in 2021 best matches Community None in 2022 with Jaccard=0.000
# Community 7 in 2021 best matches Community None in 2022 with Jaccard=0.000
#
# --- Matching Communities from Year 2022 to Year 2023 ---
# Community 0 in 2022 best matches Community 5 in 2023 with Jaccard=0.050
# Community 1 in 2022 best matches Community 2 in 2023 with Jaccard=0.045
# Community 2 in 2022 best matches Community None in 2023 with Jaccard=0.000
# Community 3 in 2022 best matches Community None in 2023 with Jaccard=0.000
# Community 4 in 2022 best matches Community 1 in 2023 with Jaccard=0.071
# Community 5 in 2022 best matches Community None in 2023 with Jaccard=0.000
# Community 6 in 2022 best matches Community None in 2023 with Jaccard=0.000
#
# --- Matching Communities from Year 2023 to Year 2024 ---
# Community 0 in 2023 best matches Community None in 2024 with Jaccard=0.000
# Community 1 in 2023 best matches Community 2 in 2024 with Jaccard=0.062
# Community 2 in 2023 best matches Community 10 in 2024 with Jaccard=0.143
# Community 3 in 2023 best matches Community 0 in 2024 with Jaccard=0.043
# Community 4 in 2023 best matches Community None in 2024 with Jaccard=0.000
# Community 5 in 2023 best matches Community 2 in 2024 with Jaccard=0.100
# Community 6 in 2023 best matches Community None in 2024 with Jaccard=0.000
